# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ver a img
import cv2 # lib opencv
from google.colab.patches import cv2_imshow
# add variavem detector_carros
detector_carros = cv2.CascadeClassifier('/content/drive/MyDrive/Visão Computacional Guia Completo/Cascades/cars.xml')
imagem = cv2.imread('/content/drive/MyDrive/Visão Computacional Guia Completo/Images/car.jpg')

if imagem is None:
  print('Img not found')
else:
  imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
  carros = detector_carros.detectMultiScale(imagem_cinza, scaleFactor=1.03, minNeighbors=5, minSize=(20,20) ) # pega o tamanho minimo dos obj

  print(f"Tot the car detect: {len(carros)}")
  print("Coordenadas the car: ", carros)

for (x, y, w, h) in carros:
  cv2.rectangle(imagem, (x, y), (x + w, y + h), (0, 0, 255), 2)
  #ver tamanhos dos carros
  len(carros)
  print(carros)
cv2_imshow(imagem)
# Out:
# Tot the car detect: 8
# Coordenadas the car:  [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# [[ 74  75  32  32]
#  [221  87  35  35]
#  [365 110  46  46]
#  [190 147  46  46]
#  [103 149  81  81]
#  [208 191  32  32]
#  [295 191  53  53]
#  [220 200  84  84]]
# <PIL.Image.Image image mode=RGB size=468x286>
