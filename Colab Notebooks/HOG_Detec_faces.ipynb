# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab.patches import cv2_imshow
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import dlib # lib mais utilizada em visao computacional
import cv2

# %%
# Detec Faces_HOG
imagem = cv2.imread('/content/drive/MyDrive/Visão Computacional Guia Completo/Images/people2.jpg')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1023x537>

# %%
# criar uma variavel usando a lib HOG
detector_face_hog = dlib.get_frontal_face_detector()

# %%
# variavel para salvar as deteccoes
deteccoes = detector_face_hog(imagem, 4) # 1 pega a escala da imagem original, qto maior o numero mais tempo para executar, as caixas em volta das faces sao menores entao a deteccao eh melhor

# %%
deteccoes, len(deteccoes) # chama a variavel
# Out:
# (rectangles[[(425, 38) (465, 78)], [(385, 60) (425, 100)], [(719, 105) (759, 145)], [(911, 69) (951, 109)], [(830, 100) (871, 140)], [(666, 91) (699, 124)], [(483, 78) (523, 118)], [(603, 69) (643, 109)], [(777, 60) (817, 100)], [(95, 87) (135, 127)], [(171, 42) (211, 82)], [(237, 51) (278, 91)], [(322, 51) (362, 91)], [(545, 65) (585, 105)]],
#  14)

# %%
# retorno de todas as faces encontradas
for face in deteccoes:
  #print(face)
  # ver valores x,y,w,h
  #print(face.left(), face.top(), face.right(), face.bottom()) # com esses valores criamos baldbox das deteccoes

  # criar a variavel para acessar
  l, r, t, b = face.left(), face.right(), face.top(), face.bottom()
  cv2.rectangle(imagem, (l,t), (r,b), (0,255,0), 2)
  cv2_imshow(imagem)
  #print(l, r, t, b)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
